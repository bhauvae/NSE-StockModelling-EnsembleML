# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
d = pd.read_pickle("./scores_untouched.pkl")
df = pd.read_pickle("./scores.pkl")

# %%
df.mean(numeric_only=True)
# Out:
# 5y  svm_acc     0.522212
#     knn_acc     0.796387
#     rf_acc      0.839543
#     xgb_acc     0.874492
#     lstm_acc    0.753263
# 2y  svm_acc     0.521127
#     knn_acc     0.672059
#     rf_acc      0.826916
#     gb_acc      0.584969
#     xgb_acc     0.856141
# 1y  svm_acc     0.509231
#     knn_acc     0.681350
#     rf_acc      0.826185
#     gb_acc      0.567246
#     lstm_acc    0.674562
# dtype: float64

# %%
ML = ["SVM", "kNN", "Rf", "XGb", "LSTM"]
averages = df["5y"].mean(numeric_only=True)

plt.figure(figsize=(10, 6))
plt.grid(axis='y', linestyle='--', alpha=0.5)
x = range(len(averages.index))
bar_width = 0.35

bars = plt.bar(x, averages.values, width=bar_width, label='5 years', alpha=1)

# Adding scores on top of the bars
for bar, score in zip(bars, averages.values):
    bar_center = bar.get_x() + (bar.get_width() / 2)
    plt.text(bar_center, bar.get_height() + 0.01, f'{score:.2f}', ha='center', color='black', fontsize=9)

plt.xlabel('ML Models')
plt.ylabel('Accuracy Scores')
plt.yticks(np.arange(0, 1.1, 0.1))
plt.xticks([i for i in x], ML)
plt.legend()
plt.tight_layout()
plt.show()

# %%
ML = ["SVM", "KNN", "RF","GB", "XGB", "LSTM"]

d5 = d["5y"][["svm_acc","knn_acc","rf_acc","gb_acc","xgb_acc","lstm_acc"]]
d2 = d["2y"][["svm_acc","knn_acc","rf_acc","gb_acc","xgb_acc","lstm_acc"]]
d1 = d["1y"][["svm_acc","knn_acc","rf_acc","gb_acc","xgb_acc","lstm_acc"]]
averages_5y = d5.mean(numeric_only=True)
averages_2y = d2.mean(numeric_only=True)
averages_1y = d1.mean(numeric_only=True)

plt.figure(figsize=(10, 6))
plt.grid(axis='y', linestyle='--', alpha=0.5)
x = range(len(averages_5y.index))
bar_width = 0.25  # Adjust the bar width for better spacing

# Create bars for each set of scores
bars_5y = plt.bar(x, averages_5y.values, width=bar_width, label='5 years', alpha=0.7)
bars_2y = plt.bar([i + bar_width for i in x], averages_2y.values, width=bar_width, label='2 years', alpha=0.7)
bars_1y = plt.bar([i + 2 * bar_width for i in x], averages_1y.values, width=bar_width, label='1 year', alpha=0.7)

# Adding scores on top of the bars
for bar, score in zip(bars_5y , averages_5y.values ):
    bar_center = bar.get_x() + (bar.get_width() / 2)
    # plt.text(bar_center, bar.get_height() + 0.01, f'{score:.2f}', ha='center', color='black', fontsize=8,  alpha=0.7)

for bar, score in zip(bars_2y , averages_2y.values ):
    bar_center = bar.get_x() + (bar.get_width() / 2)
    # plt.text(bar_center, bar.get_height() + 0.01, f'{score:.2f}', ha='center', color='black', fontsize=8,  alpha=0.7)
    
for bar, score in zip( bars_1y, averages_1y.values):
    bar_center = bar.get_x() + (bar.get_width() / 2)
    # plt.text(bar_center, bar.get_height() + 0.01, f'{score:.2f}', ha='center', color='black', fontsize=8,  alpha=0.7)

plt.xlabel('Machine Learning Models')
plt.ylabel('Accuracy Scores')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.xticks([i + bar_width for i in x], ML)
plt.legend(loc="upper left", title="Time Frame")

plt.tight_layout()


# Set the DPI (dots per inch) to a high value for high quality
dpi = 500  # Adjust this value as needed for your desired quality

# Save the plot as a PNG image with high quality
plt.savefig('acc_scores.png', dpi=dpi, bbox_inches='tight')

# Show the plot (optional)

plt.show()

# %%
nifty_50 = [
    "ADANIPORTS.NS", "ASIANPAINT.NS", "AXISBANK.NS", "BAJAJ-AUTO.NS", "BAJFINANCE.NS",
    "BAJAJFINSV.NS", "BHARTIARTL.NS", "BPCL.NS", "BRITANNIA.NS", "CIPLA.NS",
    "COALINDIA.NS", "DIVISLAB.NS", "DRREDDY.NS", "EICHERMOT.NS", "GRASIM.NS",
    "HCLTECH.NS", "HDFCBANK.NS", "HDFCLIFE.NS", "HEROMOTOCO.NS", "HINDALCO.NS",
    "HINDUNILVR.NS", "ICICIBANK.NS", "INDUSINDBK.NS", "INFY.NS", "ITC.NS",
    "JSWSTEEL.NS", "KOTAKBANK.NS", "LT.NS", "M&M.NS", "MARUTI.NS",
     "NTPC.NS", "ONGC.NS", "POWERGRID.NS", "RELIANCE.NS",
    "SHREECEM.NS", "SBIN.NS", "SBILIFE.NS", "TATAMOTORS.NS", "TATASTEEL.NS",
    "TCS.NS", "TATACONSUM.NS", "TECHM.NS", "TITAN.NS", "ULTRACEMCO.NS",
    "UPL.NS", "WIPRO.NS", "ADANIENT.NS", "DIVISLAB.NS", "IOC.NS"
]
nifty = d.loc[nifty_50]
nifty
# Out:
#                      5y                                                     \
#                 svm_acc  svm_prec svm_recall    svm_f1   knn_acc  knn_prec
# ticker
# ADANIPORTS.NS  0.543147  0.543147        1.0  0.703947  0.781726  0.762295
# ASIANPAINT.NS  0.553299  0.553299        1.0  0.712418  0.822335  0.776119
# AXISBANK.NS    0.558376  0.558376        1.0  0.716612  0.802030  0.793388
# BAJAJ-AUTO.NS  0.593909  0.593909        1.0  0.745223  0.802030  0.774648
# BAJFINANCE.NS  0.573604  0.573604        1.0  0.729032  0.857868  0.889908
# BAJAJFINSV.NS  0.553299  0.553299        1.0  0.712418  0.822335  0.836364
# BHARTIARTL.NS  0.583756  0.583756        1.0  0.737179  0.761421  0.746377
# BPCL.NS        0.522843  0.000000        0.0  0.000000  0.817259  0.784314
# BRITANNIA.NS   0.507614  0.507614        1.0  0.673401  0.776650  0.785714
# CIPLA.NS       0.553299  0.553299        1.0  0.712418  0.807107  0.819820
# ...

# %%
ML = ["SVM", "KNN", "RF","GB", "XGB", "LSTM"]

d5 = nifty["5y"][["svm_acc","knn_acc","rf_acc","gb_acc","xgb_acc","lstm_acc"]]
d2 = nifty["2y"][["svm_acc","knn_acc","rf_acc","gb_acc","xgb_acc","lstm_acc"]]
d1 = nifty["1y"][["svm_acc","knn_acc","rf_acc","gb_acc","xgb_acc","lstm_acc"]]
averages_5y = d5.mean(numeric_only=True)
averages_2y = d2.mean(numeric_only=True)
averages_1y = d1.mean(numeric_only=True)

plt.figure(figsize=(10, 6))
plt.grid(axis='y', linestyle='--', alpha=0.5)
x = range(len(averages_5y.index))
bar_width = 0.25  # Adjust the bar width for better spacing

# Create bars for each set of scores
bars_5y = plt.bar(x, averages_5y.values, width=bar_width, label='5 years', alpha=0.7)
bars_2y = plt.bar([i + bar_width for i in x], averages_2y.values, width=bar_width, label='2 years', alpha=0.7)
bars_1y = plt.bar([i + 2 * bar_width for i in x], averages_1y.values, width=bar_width, label='1 year', alpha=0.7)

# Adding scores on top of the bars
for bar, score in zip(bars_5y , averages_5y.values ):
    bar_center = bar.get_x() + (bar.get_width() / 2)
    # plt.text(bar_center, bar.get_height() + 0.01, f'{score:.2f}', ha='center', color='black', fontsize=8,  alpha=0.7)

for bar, score in zip(bars_2y , averages_2y.values ):
    bar_center = bar.get_x() + (bar.get_width() / 2)
    # plt.text(bar_center, bar.get_height() + 0.01, f'{score:.2f}', ha='center', color='black', fontsize=8,  alpha=0.7)
    
for bar, score in zip( bars_1y, averages_1y.values):
    bar_center = bar.get_x() + (bar.get_width() / 2)
    # plt.text(bar_center, bar.get_height() + 0.01, f'{score:.2f}', ha='center', color='black', fontsize=8,  alpha=0.7)

plt.xlabel('Machine Learning Models')
plt.ylabel('Accuracy Scores')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.xticks([i + bar_width for i in x], ML)
plt.legend(loc="upper left", title="Time Frame")
plt.tight_layout()


# Set the DPI (dots per inch) to a high value for high quality
dpi = 500  # Adjust this value as needed for your desired quality

# Save the plot as a PNG image with high quality
plt.savefig('acc_scores_nifty50.png', dpi=dpi, bbox_inches='tight')

# Show the plot (optional)

plt.show()

# %%
nifty_500 = [
    "3MINDIA.NS", "ABB.NS", "ACC.NS", "ADANIGREEN.NS", "ADANIPORTS.NS",
    "ADANIPOWER.NS", "ADANITRANS.NS", "ABCAPITAL.NS", "ADVENZYMES.NS", "AEGISCHEM.NS",
    "AFFLE.NS", "AJANTPHARM.NS", "AKZOINDIA.NS", "APLAPOLLO.NS", "ALKEM.NS",
    "ALKYLAMINE.NS", "AMARAJABAT.NS", "AMBER.NS", "AMBUJACEM.NS", "APOLLOHOSP.NS",
    "APOLLOTYRE.NS", "ARVINDFASN.NS", "ASAHIINDIA.NS", "ASHOKLEY.NS", "ASHOKA.NS",
    "ASIANPAINT.NS", "ASTERDM.NS", "ASTRAZEN.NS", "ASTRAL.NS", "ATUL.NS",
    "AUROPHARMA.NS", "AVANTIFEED.NS", "DMART.NS", "AXISBANK.NS", "BAJAJ-AUTO.NS",
    "BAJAJCON.NS", "BAJAJELEC.NS", "BAJFINANCE.NS", "BAJAJFINSV.NS", "BAJAJHLDNG.NS",
    "BALKRISIND.NS", "BALMLAWRIE.NS", "BALRAMCHIN.NS", "BANDHANBNK.NS", "BANKBARODA.NS",
    "BANKINDIA.NS", "MAHABANK.NS", "BASF.NS", "BEML.NS", "BERGEPAINT.NS",
    "BDL.NS", "BEL.NS", "BHARATFORG.NS", "BHEL.NS", "BPCL.NS",
    "BHARTIARTL.NS", "INFRATEL.NS", "BIOCON.NS", "BIRLACORPN.NS", "BSOFT.NS",
"][["svm_acc","knn_acc","rf_acc","gb_acc","xgb_acc","lstm_acc"]]
d1 = nifty500["1y"][["svm_acc","knn_acc","rf_acc","gb_acc","xgb_acc","lstm_acc"]]
averages_5y = d5.mean(numeric_only=True)
averages_2y = d2.mean(numeric_only=True)
averages_1y = d1.mean(numeric_only=True)

plt.figure(figsize=(10, 6))
plt.grid(axis='y', linestyle='--', alpha=0.5)
x = range(len(averages_5y.index))
bar_width = 0.25  # Adjust the bar width for better spacing

# Create bars for each set of scores
bars_5y = plt.bar(x, averages_5y.values, width=bar_width, label='5 years', alpha=0.7)
bars_2y = plt.bar([i + bar_width for i in x], averages_2y.values, width=bar_width, label='2 years', alpha=0.7)
bars_1y = plt.bar([i + 2 * bar_width for i in x], averages_1y.values, width=bar_width, label='1 year', alpha=0.7)

# Adding scores on top of the bars
for bar, score in zip(bars_5y , averages_5y.values ):
    bar_center = bar.get_x() + (bar.get_width() / 2)
    # plt.text(bar_center, bar.get_height() + 0.01, f'{score:.2f}', ha='center', color='black', fontsize=8,  alpha=0.7)

for bar, score in zip(bars_2y , averages_2y.values ):
    bar_center = bar.get_x() + (bar.get_width() / 2)
    # plt.text(bar_center, bar.get_height() + 0.01, f'{score:.2f}', ha='center', color='black', fontsize=8,  alpha=0.7)
    
for bar, score in zip( bars_1y, averages_1y.values):
    bar_center = bar.get_x() + (bar.get_width() / 2)
    # plt.text(bar_center, bar.get_height() + 0.01, f'{score:.2f}', ha='center', color='black', fontsize=8,  alpha=0.7)

plt.xlabel('Machine Learning Models')
plt.ylabel('Accuracy Scores')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.xticks([i + bar_width for i in x], ML)
plt.legend(loc="upper left", title="Time Frame")
plt.tight_layout()


# Set the DPI (dots per inch) to a high value for high quality
dpi = 500  # Adjust this value as needed for your desired quality

# Save the plot as a PNG image with high quality
plt.savefig('acc_scores_nifty500.png', dpi=dpi, bbox_inches='tight')

# Show the plot (optional)

plt.show()

# %%
df = d["5y"]

# Create a new DataFrame to store the average scores by algorithm type and metric
averages_by_algorithm = pd.DataFrame(columns=['svm', 'knn', 'rf', 'gb', 'xgb', 'lstm'], index=["acc","prec","recall","f1"])

# Define a mapping of labels for the legends
legend_labels = {
    'acc': 'Accuracy',
    'prec': 'Precision',
    'recall': 'Recall',
    'f1': 'F1-Score'
}

# Iterate through the columns and calculate the average for each metric and algorithm type
for metric, label in legend_labels.items():
    averages = []
    for algorithm in ['svm', 'knn', 'rf', 'gb', 'xgb', 'lstm']:
        columns_to_average = [f'{algorithm}_{metric}']
        average_score = df[columns_to_average].mean()
        averages_by_algorithm.loc[metric , algorithm] = average_score.values
    
    
averages_by_algorithm.index = ['Accuracy','Precision', 'Recall','F1-Score']
df = averages_by_algorithm


# Define the metrics
metrics = df.index

# Define the models
models = df.columns

# Create subplots
fig, ax = plt.subplots(figsize=(12, 6))
plt.grid(axis='y', linestyle='--', alpha=0.25)
# Width of each bar
bar_width = 0.15

# Index for x-axis locations
x = np.arange(len(models))

# Iterate through metrics and create grouped bar plots
for i, metric in enumerate(metrics):
    ax.bar(x + i * bar_width, df.loc[metric], width=bar_width, label=metric.capitalize(), alpha=0.7)
    
    # # Annotate the bars with their values
    # for j, score in enumerate(df.loc[metric]):
    #     ax.text(x[j] + i * bar_width, score + 0.01, f'{score:.2f}', ha='center', va='bottom', fontsize=8, alpha=0.7)

# Set x-axis labels and tick locations
ML = ["SVM", "KNN", "RF","GB", "XGB", "LSTM"]
ax.set_xticks(x + ((len(metrics) - 1) / 2) * bar_width)
ax.set_xticklabels(ML)
ax.set_xlabel('Machine Learning Models')

# Set y-axis label
ax.set_ylabel('Scores')

# Add a legend
ax.legend(loc="upper left",title='Metrics')

# Show the plot
plt.tight_layout()
# Set the DPI (dots per inch) to a high value for high quality
dpi = 500  # Adjust this value as needed for your desired quality

# Save the plot as a PNG image with high quality
plt.savefig('all_scores_nse_5y.png', dpi=dpi, bbox_inches='tight')

# Show the plot (optional)

plt.show()

# %%
df = d["2y"]

# Create a new DataFrame to store the average scores by algorithm type and metric
averages_by_algorithm = pd.DataFrame(columns=['svm', 'knn', 'rf', 'gb', 'xgb', 'lstm'], index=["acc","prec","recall","f1"])

# Define a mapping of labels for the legends
legend_labels = {
    'acc': 'Accuracy',
    'prec': 'Precision',
    'recall': 'Recall',
    'f1': 'F1-Score'
}

# Iterate through the columns and calculate the average for each metric and algorithm type
for metric, label in legend_labels.items():
    averages = []
    for algorithm in ['svm', 'knn', 'rf', 'gb', 'xgb', 'lstm']:
        columns_to_average = [f'{algorithm}_{metric}']
        average_score = df[columns_to_average].mean()
        averages_by_algorithm.loc[metric , algorithm] = average_score.values
    
    
averages_by_algorithm.index = ['Accuracy','Precision', 'Recall','F1-Score']
df = averages_by_algorithm


# Define the metrics
metrics = df.index

# Define the models
models = df.columns

# Create subplots
fig, ax = plt.subplots(figsize=(12, 6))
plt.grid(axis='y', linestyle='--', alpha=0.25)
# Width of each bar
bar_width = 0.15

# Index for x-axis locations
x = np.arange(len(models))

# Iterate through metrics and create grouped bar plots
for i, metric in enumerate(metrics):
    ax.bar(x + i * bar_width, df.loc[metric], width=bar_width, label=metric.capitalize(), alpha=0.7)
    
    # # Annotate the bars with their values
    # for j, score in enumerate(df.loc[metric]):
    #     ax.text(x[j] + i * bar_width, score + 0.01, f'{score:.2f}', ha='center', va='bottom', fontsize=8, alpha=0.7)

# Set x-axis labels and tick locations
ML = ["SVM", "KNN", "RF","GB", "XGB", "LSTM"]
ax.set_xticks(x + ((len(metrics) - 1) / 2) * bar_width)
ax.set_xticklabels(ML)
ax.set_xlabel('Machine Learning Models')

# Set y-axis label
ax.set_ylabel('Scores')

# Add a legend
ax.legend(loc="upper left",title='Metrics')

# Show the plot
plt.tight_layout()
# Set the DPI (dots per inch) to a high value for high quality
dpi = 500  # Adjust this value as needed for your desired quality

# Save the plot as a PNG image with high quality
plt.savefig('all_scores_nse_2y.png', dpi=dpi, bbox_inches='tight')

# Show the plot (optional)

plt.show()

# %%
df = d["1y"]

# Create a new DataFrame to store the average scores by algorithm type and metric
averages_by_algorithm = pd.DataFrame(columns=['svm', 'knn', 'rf', 'gb', 'xgb', 'lstm'], index=["acc","prec","recall","f1"])

# Define a mapping of labels for the legends
legend_labels = {
    'acc': 'Accuracy',
    'prec': 'Precision',
    'recall': 'Recall',
    'f1': 'F1-Score'
}

# Iterate through the columns and calculate the average for each metric and algorithm type
for metric, label in legend_labels.items():
    averages = []
    for algorithm in ['svm', 'knn', 'rf', 'gb', 'xgb', 'lstm']:
        columns_to_average = [f'{algorithm}_{metric}']
        average_score = df[columns_to_average].mean()
        averages_by_algorithm.loc[metric , algorithm] = average_score.values
    
    
averages_by_algorithm.index = ['Accuracy','Precision', 'Recall','F1-Score']
df = averages_by_algorithm


# Define the metrics
metrics = df.index

# Define the models
models = df.columns

# Create subplots
fig, ax = plt.subplots(figsize=(12, 6))
plt.grid(axis='y', linestyle='--', alpha=0.25)
# Width of each bar
bar_width = 0.15

# Index for x-axis locations
x = np.arange(len(models))

# Iterate through metrics and create grouped bar plots
for i, metric in enumerate(metrics):
    ax.bar(x + i * bar_width, df.loc[metric], width=bar_width, label=metric.capitalize(), alpha=0.7)
    
    # Annotate the bars with their values
    for j, score in enumerate(df.loc[metric]):
        ax.text(x[j] + i * bar_width, score + 0.01, f'{score:.2f}', ha='center', va='bottom', fontsize=8, alpha=0.7)

# Set x-axis labels and tick locations
ML = ["SVM", "KNN", "RF","GB", "XGB", "LSTM"]
ax.set_xticks(x + ((len(metrics) - 1) / 2) * bar_width)
ax.set_xticklabels(ML)
ax.set_xlabel('Machine Learning Models')

# Set y-axis label
ax.set_ylabel('Scores')

# Add a legend
ax.legend(loc="upper left",title='Metrics')

# Show the plot
plt.tight_layout()
# Set the DPI (dots per inch) to a high value for high quality
dpi = 500  # Adjust this value as needed for your desired quality

# Save the plot as a PNG image with high quality
plt.savefig('all_scores_nse_1y.png', dpi=dpi, bbox_inches='tight')

# Show the plot (optional)

plt.show()

# %%
df = nifty["5y"]

# Create a new DataFrame to store the average scores by algorithm type and metric
averages_by_algorithm = pd.DataFrame(columns=['svm', 'knn', 'rf', 'gb', 'xgb', 'lstm'], index=["acc","prec","recall","f1"])

# Define a mapping of labels for the legends
legend_labels = {
    'acc': 'Accuracy',
    'prec': 'Precision',
    'recall': 'Recall',
    'f1': 'F1-Score'
}

# Iterate through the columns and calculate the average for each metric and algorithm type
for metric, label in legend_labels.items():
    averages = []
    for algorithm in ['svm', 'knn', 'rf', 'gb', 'xgb', 'lstm']:
        columns_to_average = [f'{algorithm}_{metric}']
        average_score = df[columns_to_average].mean()
        averages_by_algorithm.loc[metric , algorithm] = average_score.values
    
    
averages_by_algorithm.index = ['Accuracy','Precision', 'Recall','F1-Score']
df = averages_by_algorithm


# Define the metrics
metrics = df.index

# Define the models
models = df.columns

# Create subplots
fig, ax = plt.subplots(figsize=(12, 6))
plt.grid(axis='y', linestyle='--', alpha=0.25)
# Width of each bar
bar_width = 0.15

# Index for x-axis locations
x = np.arange(len(models))

# Iterate through metrics and create grouped bar plots
for i, metric in enumerate(metrics):
    ax.bar(x + i * bar_width, df.loc[metric], width=bar_width, label=metric.capitalize(), alpha=0.7)
    
    # # Annotate the bars with their values
    # for j, score in enumerate(df.loc[metric]):
    #     ax.text(x[j] + i * bar_width, score + 0.01, f'{score:.2f}', ha='center', va='bottom', fontsize=8, alpha=0.7)

# Set x-axis labels and tick locations
ML = ["SVM", "KNN", "RF","GB", "XGB", "LSTM"]
ax.set_xticks(x + ((len(metrics) - 1) / 2) * bar_width)
ax.set_xticklabels(ML)
ax.set_xlabel('Machine Learning Models')

# Set y-axis label
ax.set_ylabel('Scores')

# Add a legend
ax.legend(loc="upper left",title='Metrics')

# Show the plot
plt.tight_layout()
# Set the DPI (dots per inch) to a high value for high quality
dpi = 500  # Adjust this value as needed for your desired quality

# Save the plot as a PNG image with high quality
plt.savefig('all_scores_nifty50_5y.png', dpi=dpi, bbox_inches='tight')

# Show the plot (optional)

plt.show()

# %%
df = nifty["2y"]

# Create a new DataFrame to store the average scores by algorithm type and metric
averages_by_algorithm = pd.DataFrame(columns=['svm', 'knn', 'rf', 'gb', 'xgb', 'lstm'], index=["acc","prec","recall","f1"])

# Define a mapping of labels for the legends
legend_labels = {
    'acc': 'Accuracy',
    'prec': 'Precision',
    'recall': 'Recall',
    'f1': 'F1-Score'
}

# Iterate through the columns and calculate the average for each metric and algorithm type
for metric, label in legend_labels.items():
    averages = []
    for algorithm in ['svm', 'knn', 'rf', 'gb', 'xgb', 'lstm']:
        columns_to_average = [f'{algorithm}_{metric}']
        average_score = df[columns_to_average].mean()
        averages_by_algorithm.loc[metric , algorithm] = average_score.values
    
    
averages_by_algorithm.index = ['Accuracy','Precision', 'Recall','F1-Score']
df = averages_by_algorithm


# Define the metrics
metrics = df.index

# Define the models
models = df.columns

# Create subplots
fig, ax = plt.subplots(figsize=(12, 6))
plt.grid(axis='y', linestyle='--', alpha=0.25)
# Width of each bar
bar_width = 0.15

# Index for x-axis locations
x = np.arange(len(models))

# Iterate through metrics and create grouped bar plots
for i, metric in enumerate(metrics):
    ax.bar(x + i * bar_width, df.loc[metric], width=bar_width, label=metric.capitalize(), alpha=0.7)
    
    # # Annotate the bars with their values
    # for j, score in enumerate(df.loc[metric]):
    #     ax.text(x[j] + i * bar_width, score + 0.01, f'{score:.2f}', ha='center', va='bottom', fontsize=8, alpha=0.7)

# Set x-axis labels and tick locations
ML = ["SVM", "KNN", "RF","GB", "XGB", "LSTM"]
ax.set_xticks(x + ((len(metrics) - 1) / 2) * bar_width)
ax.set_xticklabels(ML)
ax.set_xlabel('Machine Learning Models')

# Set y-axis label
ax.set_ylabel('Scores')

# Add a legend
ax.legend(loc="upper left",title='Metrics')

# Show the plot
plt.tight_layout()
# Set the DPI (dots per inch) to a high value for high quality
dpi = 500  # Adjust this value as needed for your desired quality

# Save the plot as a PNG image with high quality
plt.savefig('all_scores_nifty50_2y.png', dpi=dpi, bbox_inches='tight')

# Show the plot (optional)

plt.show()

# %%
df = nifty["1y"]

# Create a new DataFrame to store the average scores by algorithm type and metric
averages_by_algorithm = pd.DataFrame(columns=['svm', 'knn', 'rf', 'gb', 'xgb', 'lstm'], index=["acc","prec","recall","f1"])

# Define a mapping of labels for the legends
legend_labels = {
    'acc': 'Accuracy',
    'prec': 'Precision',
    'recall': 'Recall',
    'f1': 'F1-Score'
}

# Iterate through the columns and calculate the average for each metric and algorithm type
for metric, label in legend_labels.items():
    averages = []
    for algorithm in ['svm', 'knn', 'rf', 'gb', 'xgb', 'lstm']:
        columns_to_average = [f'{algorithm}_{metric}']
        average_score = df[columns_to_average].mean()
        averages_by_algorithm.loc[metric , algorithm] = average_score.values
    
    
averages_by_algorithm.index = ['Accuracy','Precision', 'Recall','F1-Score']
df = averages_by_algorithm


# Define the metrics
metrics = df.index

# Define the models
models = df.columns

# Create subplots
fig, ax = plt.subplots(figsize=(12, 6))
plt.grid(axis='y', linestyle='--', alpha=0.25)
# Width of each bar
bar_width = 0.15

# Index for x-axis locations
x = np.arange(len(models))

# Iterate through metrics and create grouped bar plots
for i, metric in enumerate(metrics):
    ax.bar(x + i * bar_width, df.loc[metric], width=bar_width, label=metric.capitalize(), alpha=0.7)
    
    # # Annotate the bars with their values
    # for j, score in enumerate(df.loc[metric]):
    #     ax.text(x[j] + i * bar_width, score + 0.01, f'{score:.2f}', ha='center', va='bottom', fontsize=8, alpha=0.7)

# Set x-axis labels and tick locations
ML = ["SVM", "KNN", "RF","GB", "XGB", "LSTM"]
ax.set_xticks(x + ((len(metrics) - 1) / 2) * bar_width)
ax.set_xticklabels(ML)
ax.set_xlabel('Machine Learning Models')

# Set y-axis label
ax.set_ylabel('Scores')

# Add a legend
ax.legend(loc="upper left",title='Metrics')

# Show the plot
plt.tight_layout()
# Set the DPI (dots per inch) to a high value for high quality
dpi = 500  # Adjust this value as needed for your desired quality

# Save the plot as a PNG image with high quality
plt.savefig('all_scores_nifty50_1y.png', dpi=dpi, bbox_inches='tight')

# Show the plot (optional)

plt.show()

# %%
df = nifty500["5y"]

# Create a new DataFrame to store the average scores by algorithm type and metric
averages_by_algorithm = pd.DataFrame(columns=['svm', 'knn', 'rf', 'gb', 'xgb', 'lstm'], index=["acc","prec","recall","f1"])

# Define a mapping of labels for the legends
legend_labels = {
    'acc': 'Accuracy',
    'prec': 'Precision',
    'recall': 'Recall',
    'f1': 'F1-Score'
}

# Iterate through the columns and calculate the average for each metric and algorithm type
for metric, label in legend_labels.items():
    averages = []
    for algorithm in ['svm', 'knn', 'rf', 'gb', 'xgb', 'lstm']:
        columns_to_average = [f'{algorithm}_{metric}']
        average_score = df[columns_to_average].mean()
        averages_by_algorithm.loc[metric , algorithm] = average_score.values
    
    
averages_by_algorithm.index = ['Accuracy','Precision', 'Recall','F1-Score']
df = averages_by_algorithm


# Define the metrics
metrics = df.index

# Define the models
models = df.columns

# Create subplots
fig, ax = plt.subplots(figsize=(12, 6))
plt.grid(axis='y', linestyle='--', alpha=0.25)
# Width of each bar
bar_width = 0.15

# Index for x-axis locations
x = np.arange(len(models))

# Iterate through metrics and create grouped bar plots
for i, metric in enumerate(metrics):
    ax.bar(x + i * bar_width, df.loc[metric], width=bar_width, label=metric.capitalize(), alpha=0.7)
    
    # # Annotate the bars with their values
    # for j, score in enumerate(df.loc[metric]):
    #     ax.text(x[j] + i * bar_width, score + 0.01, f'{score:.2f}', ha='center', va='bottom', fontsize=8, alpha=0.7)

# Set x-axis labels and tick locations
ML = ["SVM", "KNN", "RF","GB", "XGB", "LSTM"]
ax.set_xticks(x + ((len(metrics) - 1) / 2) * bar_width)
ax.set_xticklabels(ML)
ax.set_xlabel('Machine Learning Models')

# Set y-axis label
ax.set_ylabel('Scores')

# Add a legend
ax.legend(loc="upper left",title='Metrics')

# Show the plot
plt.tight_layout()
# Set the DPI (dots per inch) to a high value for high quality
dpi = 500  # Adjust this value as needed for your desired quality

# Save the plot as a PNG image with high quality
plt.savefig('all_scores_nifty500_5y.png', dpi=dpi, bbox_inches='tight')

# Show the plot (optional)

plt.show()

# %%
df = nifty500["2y"]

# Create a new DataFrame to store the average scores by algorithm type and metric
averages_by_algorithm = pd.DataFrame(columns=['svm', 'knn', 'rf', 'gb', 'xgb', 'lstm'], index=["acc","prec","recall","f1"])

# Define a mapping of labels for the legends
legend_labels = {
    'acc': 'Accuracy',
    'prec': 'Precision',
    'recall': 'Recall',
    'f1': 'F1-Score'
}

# Iterate through the columns and calculate the average for each metric and algorithm type
for metric, label in legend_labels.items():
    averages = []
    for algorithm in ['svm', 'knn', 'rf', 'gb', 'xgb', 'lstm']:
        columns_to_average = [f'{algorithm}_{metric}']
        average_score = df[columns_to_average].mean()
        averages_by_algorithm.loc[metric , algorithm] = average_score.values
    
    
averages_by_algorithm.index = ['Accuracy','Precision', 'Recall','F1-Score']
df = averages_by_algorithm


# Define the metrics
metrics = df.index

# Define the models
models = df.columns

# Create subplots
fig, ax = plt.subplots(figsize=(12, 6))
plt.grid(axis='y', linestyle='--', alpha=0.25)
# Width of each bar
bar_width = 0.15

# Index for x-axis locations
x = np.arange(len(models))

# Iterate through metrics and create grouped bar plots
for i, metric in enumerate(metrics):
    ax.bar(x + i * bar_width, df.loc[metric], width=bar_width, label=metric.capitalize(), alpha=0.7)
    
    # # Annotate the bars with their values
    # for j, score in enumerate(df.loc[metric]):
    #     ax.text(x[j] + i * bar_width, score + 0.01, f'{score:.2f}', ha='center', va='bottom', fontsize=8, alpha=0.7)

# Set x-axis labels and tick locations
ML = ["SVM", "KNN", "RF","GB", "XGB", "LSTM"]
ax.set_xticks(x + ((len(metrics) - 1) / 2) * bar_width)
ax.set_xticklabels(ML)
ax.set_xlabel('Machine Learning Models')

# Set y-axis label
ax.set_ylabel('Scores')

# Add a legend
ax.legend(loc="upper left",title='Metrics')

# Show the plot
plt.tight_layout()
# Set the DPI (dots per inch) to a high value for high quality
dpi = 500  # Adjust this value as needed for your desired quality

# Save the plot as a PNG image with high quality
plt.savefig('all_scores_nifty500_2y.png', dpi=dpi, bbox_inches='tight')

# Show the plot (optional)

plt.show()

# %%
df = nifty500["1y"]

# Create a new DataFrame to store the average scores by algorithm type and metric
averages_by_algorithm = pd.DataFrame(columns=['svm', 'knn', 'rf', 'gb', 'xgb', 'lstm'], index=["acc","prec","recall","f1"])

# Define a mapping of labels for the legends
legend_labels = {
    'acc': 'Accuracy',
    'prec': 'Precision',
    'recall': 'Recall',
    'f1': 'F1-Score'
}

# Iterate through the columns and calculate the average for each metric and algorithm type
for metric, label in legend_labels.items():
    averages = []
    for algorithm in ['svm', 'knn', 'rf', 'gb', 'xgb', 'lstm']:
        columns_to_average = [f'{algorithm}_{metric}']
        average_score = df[columns_to_average].mean()
        averages_by_algorithm.loc[metric , algorithm] = average_score.values
    
    
averages_by_algorithm.index = ['Accuracy','Precision', 'Recall','F1-Score']
df = averages_by_algorithm


# Define the metrics
metrics = df.index

# Define the models
models = df.columns

# Create subplots
fig, ax = plt.subplots(figsize=(12, 6))
plt.grid(axis='y', linestyle='--', alpha=0.25)
# Width of each bar
bar_width = 0.15

# Index for x-axis locations
x = np.arange(len(models))

# Iterate through metrics and create grouped bar plots
for i, metric in enumerate(metrics):
    ax.bar(x + i * bar_width, df.loc[metric], width=bar_width, label=metric.capitalize(), alpha=0.7)
    
    # # Annotate the bars with their values
    # for j, score in enumerate(df.loc[metric]):
    #     ax.text(x[j] + i * bar_width, score + 0.01, f'{score:.2f}', ha='center', va='bottom', fontsize=8, alpha=0.7)

# Set x-axis labels and tick locations
ML = ["SVM", "KNN", "RF","GB", "XGB", "LSTM"]
ax.set_xticks(x + ((len(metrics) - 1) / 2) * bar_width)
ax.set_xticklabels(ML)
ax.set_xlabel('Machine Learning Models')

# Set y-axis label
ax.set_ylabel('Scores')

# Add a legend
ax.legend(loc="upper left",title='Metrics')

# Show the plot
plt.tight_layout()
# Set the DPI (dots per inch) to a high value for high quality
dpi = 500  # Adjust this value as needed for your desired quality

# Save the plot as a PNG image with high quality
plt.savefig('all_scores_nifty500_1y.png', dpi=dpi, bbox_inches='tight')

# Show the plot (optional)

plt.show()

# %%
ML = ["SVM", "KNN", "RF","GB", "XGB", "LSTM"]

d5 = d["5y"][["svm_f1","knn_f1","rf_f1","gb_f1","xgb_f1","lstm_f1"]]
d2 = d["2y"][["svm_f1","knn_f1","rf_f1","gb_f1","xgb_f1","lstm_f1"]]
d1 = d["1y"][["svm_f1","knn_f1","rf_f1","gb_f1","xgb_f1","lstm_f1"]]
averages_5y = d5.mean(numeric_only=True)
averages_2y = d2.mean(numeric_only=True)
averages_1y = d1.mean(numeric_only=True)

plt.figure(figsize=(10, 6))
plt.grid(axis='y', linestyle='--', alpha=0.5)
x = range(len(averages_5y.index))
bar_width = 0.25  # Adjust the bar width for better spacing

# Create bars for each set of scores
bars_5y = plt.bar(x, averages_5y.values, width=bar_width, label='5 years', alpha=0.7)
bars_2y = plt.bar([i + bar_width for i in x], averages_2y.values, width=bar_width, label='2 years', alpha=0.7)
bars_1y = plt.bar([i + 2 * bar_width for i in x], averages_1y.values, width=bar_width, label='1 year', alpha=0.7)

# Adding scores on top of the bars
for bar, score in zip(bars_5y , averages_5y.values ):
    bar_center = bar.get_x() + (bar.get_width() / 2)
    # plt.text(bar_center, bar.get_height() + 0.01, f'{score:.2f}', ha='center', color='black', fontsize=8,  alpha=0.7)

for bar, score in zip(bars_2y , averages_2y.values ):
    bar_center = bar.get_x() + (bar.get_width() / 2)
    # plt.text(bar_center, bar.get_height() + 0.01, f'{score:.2f}', ha='center', color='black', fontsize=8,  alpha=0.7)
    
for bar, score in zip( bars_1y, averages_1y.values):
    bar_center = bar.get_x() + (bar.get_width() / 2)
    # plt.text(bar_center, bar.get_height() + 0.01, f'{score:.2f}', ha='center', color='black', fontsize=8,  alpha=0.7)

plt.xlabel('Machine Learning Models')
plt.ylabel('F1 Scores')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.xticks([i + bar_width for i in x], ML)
plt.legend(loc="upper left", title="Time Frame")
plt.tight_layout()


# Set the DPI (dots per inch) to a high value for high quality
dpi = 500  # Adjust this value as needed for your desired quality

# Save the plot as a PNG image with high quality
plt.savefig('f1_scores.png', dpi=dpi, bbox_inches='tight')

# Show the plot (optional)

plt.show()

# %%
ML = ["SVM", "KNN", "RF","GB", "XGB", "LSTM"]

d5 = nifty["5y"][["svm_f1","knn_f1","rf_f1","gb_f1","xgb_f1","lstm_f1"]]
d2 = nifty["2y"][["svm_f1","knn_f1","rf_f1","gb_f1","xgb_f1","lstm_f1"]]
d1 = nifty["1y"][["svm_f1","knn_f1","rf_f1","gb_f1","xgb_f1","lstm_f1"]]
averages_5y = d5.mean(numeric_only=True)
averages_2y = d2.mean(numeric_only=True)
averages_1y = d1.mean(numeric_only=True)

plt.figure(figsize=(10, 6))
plt.grid(axis='y', linestyle='--', alpha=0.5)
x = range(len(averages_5y.index))
bar_width = 0.25  # Adjust the bar width for better spacing

# Create bars for each set of scores
bars_5y = plt.bar(x, averages_5y.values, width=bar_width, label='5 years', alpha=0.7)
bars_2y = plt.bar([i + bar_width for i in x], averages_2y.values, width=bar_width, label='2 years', alpha=0.7)
bars_1y = plt.bar([i + 2 * bar_width for i in x], averages_1y.values, width=bar_width, label='1 year', alpha=0.7)

# Adding scores on top of the bars
for bar, score in zip(bars_5y , averages_5y.values ):
    bar_center = bar.get_x() + (bar.get_width() / 2)
    # plt.text(bar_center, bar.get_height() + 0.01, f'{score:.2f}', ha='center', color='black', fontsize=8,  alpha=0.7)

for bar, score in zip(bars_2y , averages_2y.values ):
    bar_center = bar.get_x() + (bar.get_width() / 2)
    # plt.text(bar_center, bar.get_height() + 0.01, f'{score:.2f}', ha='center', color='black', fontsize=8,  alpha=0.7)
    
for bar, score in zip( bars_1y, averages_1y.values):
    bar_center = bar.get_x() + (bar.get_width() / 2)
    # plt.text(bar_center, bar.get_height() + 0.01, f'{score:.2f}', ha='center', color='black', fontsize=8,  alpha=0.7)

plt.xlabel('Machine Learning Models')
plt.ylabel('F1 Scores')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.xticks([i + bar_width for i in x], ML)
plt.legend(loc="upper left", title="Time Frame")
plt.tight_layout()


# Set the DPI (dots per inch) to a high value for high quality
dpi = 500  # Adjust this value as needed for your desired quality

# Save the plot as a PNG image with high quality
plt.savefig('f1_scores_nifty50.png', dpi=dpi, bbox_inches='tight')

# Show the plot (optional)

plt.show()

# %%
ML = ["SVM", "KNN", "RF","GB", "XGB", "LSTM"]

d5 = nifty500["5y"][["svm_f1","knn_f1","rf_f1","gb_f1","xgb_f1","lstm_f1"]]
d2 = nifty500["2y"][["svm_f1","knn_f1","rf_f1","gb_f1","xgb_f1","lstm_f1"]]
d1 = nifty500["1y"][["svm_f1","knn_f1","rf_f1","gb_f1","xgb_f1","lstm_f1"]]
averages_5y = d5.mean(numeric_only=True)
averages_2y = d2.mean(numeric_only=True)
averages_1y = d1.mean(numeric_only=True)

plt.figure(figsize=(10, 6))
plt.grid(axis='y', linestyle='--', alpha=0.5)
x = range(len(averages_5y.index))
bar_width = 0.25  # Adjust the bar width for better spacing

# Create bars for each set of scores
bars_5y = plt.bar(x, averages_5y.values, width=bar_width, label='5 years', alpha=0.7)
bars_2y = plt.bar([i + bar_width for i in x], averages_2y.values, width=bar_width, label='2 years', alpha=0.7)
bars_1y = plt.bar([i + 2 * bar_width for i in x], averages_1y.values, width=bar_width, label='1 year', alpha=0.7)

# Adding scores on top of the bars
for bar, score in zip(bars_5y , averages_5y.values ):
    bar_center = bar.get_x() + (bar.get_width() / 2)
    # plt.text(bar_center, bar.get_height() + 0.01, f'{score:.2f}', ha='center', color='black', fontsize=8,  alpha=0.7)

for bar, score in zip(bars_2y , averages_2y.values ):
    bar_center = bar.get_x() + (bar.get_width() / 2)
    # plt.text(bar_center, bar.get_height() + 0.01, f'{score:.2f}', ha='center', color='black', fontsize=8,  alpha=0.7)
    
for bar, score in zip( bars_1y, averages_1y.values):
    bar_center = bar.get_x() + (bar.get_width() / 2)
    # plt.text(bar_center, bar.get_height() + 0.01, f'{score:.2f}', ha='center', color='black', fontsize=8,  alpha=0.7)

plt.xlabel('Machine Learning Models')
plt.ylabel('F1 Scores')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.xticks([i + bar_width for i in x], ML)
plt.legend(loc="upper left", title="Time Frame")
plt.tight_layout()


# Set the DPI (dots per inch) to a high value for high quality
dpi = 500  # Adjust this value as needed for your desired quality

# Save the plot as a PNG image with high quality
plt.savefig('f1_scores_nifty500.png', dpi=dpi, bbox_inches='tight')

# Show the plot (optional)

plt.show()
